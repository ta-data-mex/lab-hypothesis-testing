# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas
import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1 - Exploring the Data
#
# In this challenge, we will examine all salaries of employees of the City of Chicago. We will start by loading the dataset and examining its contents

# %%
# Run this code:

salaries = pd.read_csv('../Current_Employee_Names__Salaries__and_Position_Titles.csv')

# %% [markdown]
# Examine the `salaries` dataset using the `head` function below.

# %%
# Your code here:
salaries.head()
# Out:
#                   Name                              Job Titles  \
# 0    AARON,  JEFFERY M                                SERGEANT
# 1      AARON,  KARINA   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2  AARON,  KIMBERLEI R                CHIEF CONTRACT EXPEDITER
# 3  ABAD JR,  VICENTE M                       CIVIL ENGINEER IV
# 4    ABASCAL,  REECE E             TRAFFIC CONTROL AIDE-HOURLY
#
#          Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 0            POLICE                 F           Salary            NaN
# 1            POLICE                 F           Salary            NaN
# 2  GENERAL SERVICES                 F           Salary            NaN
# 3       WATER MGMNT                 F           Salary            NaN
# 4              OEMC                 P           Hourly           20.0
#
#    Annual Salary  Hourly Rate
# 0       101442.0          NaN
# 1        94122.0          NaN
# 2       101592.0          NaN
# 3       110064.0          NaN
# ...

# %% [markdown]
# We see from looking at the `head` function that there is quite a bit of missing data. Let's examine how much missing data is in each column. Produce this output in the cell below

# %%
# Your code here:
salaries.isna().sum()
# Out:
# Name                     0
# Job Titles               0
# Department               0
# Full or Part-Time        0
# Salary or Hourly         0
# Typical Hours        25161
# Annual Salary         8022
# Hourly Rate          25161
# dtype: int64

# %% [markdown]
# Let's also look at the count of hourly vs. salaried employees. Write the code in the cell below

# %%
# Your code here:

print(salaries["Salary or Hourly"].count())
salaries['Salary or Hourly'].value_counts().to_dict()
# Out:
# 33183
# {'Salary': 25161, 'Hourly': 8022}

# %% [markdown]
# What this information indicates is that the table contains information about two types of employees - salaried and hourly. Some columns apply only to one type of employee while other columns only apply to another kind. This is why there are so many missing values. Therefore, we will not do anything to handle the missing values.

# %% [markdown]
# There are different departments in the city. List all departments and the count of employees in each department.

# %%
# Your code here:
salaries["Department"].value_counts()
# Out:
# POLICE                   13414
# FIRE                      4641
# STREETS & SAN             2198
# OEMC                      2102
# WATER MGMNT               1879
# AVIATION                  1629
# TRANSPORTN                1140
# PUBLIC LIBRARY            1015
# GENERAL SERVICES           980
# FAMILY & SUPPORT           615
# FINANCE                    560
# HEALTH                     488
# CITY COUNCIL               411
# LAW                        407
# BUILDINGS                  269
# COMMUNITY DEVELOPMENT      207
# BUSINESS AFFAIRS           171
# COPA                       116
# BOARD OF ELECTION          107
# DoIT                        99
# PROCUREMENT                 92
# INSPECTOR GEN               87
# MAYOR'S OFFICE              85
# CITY CLERK                  84
# ANIMAL CONTRL               81
# HUMAN RESOURCES             79
# CULTURAL AFFAIRS            65
# BUDGET & MGMT               46
# ADMIN HEARNG                39
# DISABILITIES                28
# ...

# %% [markdown]
# # Challenge 2 - Hypothesis Tests
#
# In this section of the lab, we will test whether the hourly wage of all hourly workers is significantly different from $30/hr. Import the correct one sample test function from scipy and perform the hypothesis test for a 95% two sided confidence interval.

# %%
# Your code here:
from scipy.stats import ttest_1samp

# %%
#ESTSAS PRUEBAS DE UNA COLA

#HO: U=30 USD
#HI  U NO ES 30 USD

# %%
y= 30 #define el salario por hora que sea 30
hourly = salaries[salaries["Salary or Hourly"] == "Hourly"] #con esto haces un df de sólo los empleados por hora
desv = np.std(hourly["Hourly Rate"]) #obtienes la desv est
media = hourly["Hourly Rate"].mean() #obtienes media

# %%
print(desv, media)
# Out:
# 12.111817701093837 32.78855771628128

# %%
hourly
# Out:
#                            Name                         Job Titles  \
# 4             ABASCAL,  REECE E        TRAFFIC CONTROL AIDE-HOURLY
# 6         ABBATACOLA,  ROBERT J                ELECTRICAL MECHANIC
# 7            ABBATE,  JOSEPH L             POOL MOTOR TRUCK DRIVER
# 10             ABBOTT,  BETTY L                 FOSTER GRANDPARENT
# 18         ABDULLAH,  LAKENYA N                     CROSSING GUARD
# 19           ABDULLAH,  RASHAD    ELECTRICAL MECHANIC (AUTOMOTIVE)
# 21        ABDUL-SHAKUR,  TAHIR               GENERAL LABORER - DSS
# 24       ABERCROMBIE,  TIMOTHY                  MOTOR TRUCK DRIVER
# 26           ABIOYE,  ADEWOLE A         LIBRARY ASSOCIATE - HOURLY
# 33       ABRAHAMSON,  MICHAEL C   STUDENT INTERN - MAYOR'S FELLOWS
# 36          ABRAMS,  DANIELLE T                 SANITATION LABORER
# 39            ABRAMS,  SAMUEL A            POOL MOTOR TRUCK DRIVER
# 40            ABRAMS,  TIFFANY          OPERATING ENGINEER-GROUP C
# ...

# %%
#Haces la muestra
sample = np.random.normal(media, desv, 1000) #haces la muestra

# %%
ttest_1samp(sample, y) #hacemos la prueba o puedes hacer un 30 
#El valor es menor de 0.5, por lo que rechazas la hipótesis nula, lo que quiere decir que el salario por hora es significativamente
#diferente a 30 usd
# Out:
# Ttest_1sampResult(statistic=6.162652888979866, pvalue=1.0361755062917575e-09)

# %% [markdown]
# We are also curious about salaries in the police force. The chief of police in Chicago claimed in a press briefing that salaries this year are higher than last year's mean of $86000/year a year for all salaried employees. Test this one sided hypothesis using a 95% confidence interval.
#
# Hint: A one tailed test has a p-value that is half of the two tailed p-value. If our hypothesis is greater than, then to reject, the test statistic must also be positive.

# %%
#Ho u > 86000
#H1 u <= 86000

# %%
# Your code here:
police_salaried = salaries[(salaries["Department"] == "POLICE") & (salaries['Salary or Hourly'] == "Salary")]
#police_salaried = salaries[salaries["Hourly Rate"] > 0]
police_salaried
# Out:
#                          Name                              Job Titles  \
# 0           AARON,  JEFFERY M                                SERGEANT
# 1             AARON,  KARINA   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 9            ABBATE,  TERRY M                          POLICE OFFICER
# 11           ABDALLAH,  ZAID                           POLICE OFFICER
# 12     ABDELHADI,  ABDALMAHD                           POLICE OFFICER
# 14        ABDELMAJEID,  AZIZ                           POLICE OFFICER
# 22          ABEJERO,  JASON V                          POLICE OFFICER
# 25         ABFALL,  RICHARD C                          POLICE OFFICER
# 27           ABNEY,  PATRICK                           POLICE OFFICER
# 28          ABOUASSI,  CHADI                           POLICE OFFICER
# 32          ABRAHAM,  NANCY A                          POLICE OFFICER
# 34          ABRAM,  ANTHONY A                          POLICE OFFICER
# ...

# %%
police_salaried.groupby(["Salary or Hourly"]).count()
# Out:
#                    Name  Job Titles  Department  Full or Part-Time  \
# Salary or Hourly
# Salary            13404       13404       13404              13404
#
#                   Typical Hours  Annual Salary  Hourly Rate
# Salary or Hourly
# Salary                        0          13404            0

# %%
x = 86000
media = police_salaried["Annual Salary"].mean()

# %%
print(media, desv)
# Out:
# 86486.41450313339 18271.546685177447

# %%
#Hazme la muestra
muestra_pol = np.random.normal(media, desv, 1500)
muestra_pol
# Out:
# array([76454.68556029, 57758.67346562, 99646.81258707, ...,
#        83339.43734735, 95338.50973694, 97280.24434449])

# %%
#Prueba
ttest_1samp(muestra_pol, 86000)
# Out:
# Ttest_1sampResult(statistic=0.9125928039448482, pvalue=0.36160348530877295)

# %%
#Como p value es es mayor a 0.05 fallamos en rachazar la hipótesis nula. Lo que quiere decir que el salario
#sí es mayor a 86,000

# %% [markdown]
# Using the `crosstab` function, find the department that has the most hourly workers.

# %%
# Your code here:
table = pd.crosstab(salaries.Department, salaries["Salary or Hourly"])#columns = "Hourly Rate")
table.sort_values("Hourly", ascending = False).head()

#El departamento con más trabajadores por hora es Streets and San
# Out:
# Salary or Hourly  Hourly  Salary
# Department
# STREETS & SAN       1862     336
# WATER MGMNT         1513     366
# OEMC                1273     829
# AVIATION            1082     547
# GENERAL SERVICES     765     215

# %% [markdown]
# The workers from the department with the most hourly workers have complained that their hourly wage is less than $35/hour. Using a one sample t-test, test this one-sided hypothesis at the 95% confidence level.

# %%
# Your code here:
salaries[salaries["Department"]=="STREETS & SAN"].mean()  #La estadísitca dice que sí es cierto
# Out:
# Typical Hours       37.137487
# Annual Salary    83019.250000
# Hourly Rate         33.728378
# dtype: float64

# %%
#prueba
#Ho u < 35
#H1 u => 35

# %%
df = salaries[salaries["Department"]=="STREETS & SAN"]

# %%
media = df["Hourly Rate"].mean()
desv = np.std(df["Hourly Rate"])

# %%
print(media, desv)
# Out:
# 33.728378088076845 5.733701558944117

# %%
muestra = np.random.normal(media, desv, 500)

# %%
ttest_1samp(muestra, 35)
# Out:
# Ttest_1sampResult(statistic=-6.234455692398844, pvalue=9.663304285104191e-10)

# %%
#Concluimos que nuestro p values es menor que 0.05, lo que significa que rechazamos la hipótesis nula,
#Lo que significa que los salarios sí so nmenor a 34 usd por hora.

# %% [markdown]
# # Challenge 3 - Constructing Confidence Intervals
#
# While testing our hypothesis is a great way to gather empirical evidence for accepting or rejecting the hypothesis, another way to gather evidence is by creating a confidence interval. A confidence interval gives us information about the true mean of the population. So for a 95% confidence interval, we are 95% sure that the mean of the population is within the confidence interval.
# ).
#
# To read more about confidence intervals, click [here](https://en.wikipedia.org/wiki/Confidence_interval).
#
#
# In the cell below, we will construct a 95% confidence interval for the mean hourly wage of all hourly workers.
#
# The confidence interval is computed in SciPy using the `t.interval` function. You can read more about this function [here](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.t.html).
#
# To compute the confidence interval of the hourly wage, use the 0.95 for the confidence level, number of rows - 1 for degrees of freedom, the mean of the sample for the location parameter and the standard error for the scale. The standard error can be computed using [this](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.sem.html) function in SciPy.

# %%
# Your code here:
from scipy.stats import sem, t
from scipy import mean

# %%
police_salaried["Salary or Hourly"].value_counts()
# Out:
# Salary    13404
# Name: Salary or Hourly, dtype: int64

# %%
police_salaried
# Out:
#                          Name                              Job Titles  \
# 0           AARON,  JEFFERY M                                SERGEANT
# 1             AARON,  KARINA   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 9            ABBATE,  TERRY M                          POLICE OFFICER
# 11           ABDALLAH,  ZAID                           POLICE OFFICER
# 12     ABDELHADI,  ABDALMAHD                           POLICE OFFICER
# 14        ABDELMAJEID,  AZIZ                           POLICE OFFICER
# 22          ABEJERO,  JASON V                          POLICE OFFICER
# 25         ABFALL,  RICHARD C                          POLICE OFFICER
# 27           ABNEY,  PATRICK                           POLICE OFFICER
# 28          ABOUASSI,  CHADI                           POLICE OFFICER
# 32          ABRAHAM,  NANCY A                          POLICE OFFICER
# 34          ABRAM,  ANTHONY A                          POLICE OFFICER
# ...

# %%
import numpy as np, scipy.stats as st

# %% [markdown]
# Now construct the 95% confidence interval for all salaried employeed in the police in the cell below.

# %%
#Estos ya están filtrados para que no esté la policia 
st.t.interval(0.95, len(police_salaried["Annual Salary"])-1, loc=np.mean(police_salaried["Annual Salary"]))#, scale=st.sem(police2["Annual Salary"]))
# Out:
# (86484.45436213759, 86488.37464412919)

# %% [markdown]
# # Challenge 4 - Hypothesis Tests of Proportions
#
# Another type of one sample test is a hypothesis test of proportions. In this test, we examine whether the proportion of a group in our sample is significantly different than a fraction.
#
# You can read more about one sample proportion tests [here](http://sphweb.bumc.bu.edu/otlt/MPH-Modules/BS/SAS/SAS6-CategoricalData/SAS6-CategoricalData2.html).
#
# In the cell below, use the `proportions_ztest` function from `statsmodels` to perform a hypothesis test that will determine whether the number of hourly workers in the City of Chicago is significantly different from 25% at the 95% confidence level.

# %%
# Your code here:
import numpy as np
from statsmodels.stats.proportion import proportions_ztest

# %%
#Ho u = 25%
#H1 u no es igual 25%

# %%
#Obtienes la proporción de los que trabajan por hora y la población
trab_hora = len(salaries[salaries["Salary or Hourly"]== "Hourly"])
trab_todos = len(salaries)

# %%
print(trab_hora, trab_todos) #Los que trabajan por hora y todos los que trabajan
trab_hora/trab_todos
# Out:
# 8022 33183
# 0.24175029382515142

# %%
stat, proporcion = proportions_ztest(count=trab_hora, nobs=trab_todos, value=0.25)
proporcion
#proporcion2 = proporcion = proportions_ztest(trab_hora, trab_todos, value=0.95)

#Como el valor de p.values es menor a 0.05 se rechaza la Ho, y se acepta la hipótesis alternativa.
#Esto significa que el number de trabajadores por hora en Chicago es significativamente dif al 25% 


#print('{0:0.3f}'.format(proporcion))
# Out:
# 0.0004481127249057967

# %%
#Se rechaza la hipótesis nula dado que p.value <0.05, por lo que lo concluimos que el promedio de trabajadores
#por hora en Chicago difiere de 25%.
